# %%
from google.colab import drive
drive.mount('/content/drive/')
ROOT_DIR = "/content/drive/My Drive/143 project/"
# Out:
# Mounted at /content/drive/

# %%
#Food Security Status of U.S. Households with Children in 2020
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7
 
# create data
names = ['85.2 percent of households with children were food secure', 
         '7.2 percent of households with children, only adults were food insecure', 
         'low food security among children - 6.8%', 'vert low food security among children - 0.8%,']
size = [85.2 ,7.2,6.8, 0.8]
 
# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

from palettable.colorbrewer.qualitative import Pastel1_7
plt.figure(figsize=(8,8))
plt.pie(size, labels=names, colors=Pastel1_7.hex_colors)
p = plt.gcf()
p.gca().add_artist(my_circle)

# Show the graph
# plt.legend(loc="upper right")
plt.show()

# %%
# Food Insecurity by Household Characteristics
import pandas as pd
data = pd.read_excel('/content/drive/My Drive/143 project/insecurity2020.xlsx')

# %%
data
# Out:
#                                            Category  Thousands  Percent
# 0                                    All households    13754.0     10.5
# 1                            Household composition:        NaN      NaN
# 2                                With children < 18     5623.0     14.8
# 3                                With children < 6      2464.0     15.3
# 4                     Married couples with children     2329.0      9.5
# 5                        Single women with children     2704.0     27.7
# 6                          Single men with children      538.0     16.3
# 7                      Other households with child1       51.0     12.3
# 8                             With no children < 18     8131.0      8.8
# 9                               More than one adult     3887.0      7.1
# 10                               Women living alone     2302.0     11.0
# 11                                 Men living alone     1941.0     11.4
# 12                                     With elderly     2832.0      6.9
# 13                             Elderly living alone     1286.0      8.3
# 14  Race/ethnicity of household reference persons2:        NaN      NaN
# 15                               White non-Hispanic     6079.0      7.1
# 16                               Black non-Hispanic     3628.0     21.7
# 17                                        Hispanic3     3184.0     17.2
# 18                               Other non-Hispanic      861.0      8.8
# 19              Household income-to-poverty ratio4:        NaN      NaN
# 20                                       Under 1.00     3714.0     35.3
# 21                                       Under 1.30     5453.0     33.1
# 22                                       Under 1.85     7344.0     28.6
# 23                                    1.85 and over     3447.0      4.9
# 24                                   Income unknown     2962.0      8.7
# 25                              Area of residence5:        NaN      NaN
# 26                         Inside metropolitan area    11627.0     10.4
# 27                             In principal cities6     4913.0     12.7
# 28                          Not in principal cities     4948.0      8.8
# 29                        Outside metropolitan area     2127.0     11.6
# 30                                   Census region:        NaN      NaN
# 31                                        Northeast     2070.0      9.3
# 32                                          Midwest     2643.0      9.5
# 33                                            South     6234.0     12.3
# 34                                             West     2807.0      9.5

# %%
import numpy as np
my_range = range(1, 36)
plt.figure(figsize = (8,8))
my_color=np.where(data['Category']=='All households', 'orange', 'skyblue')
my_size=np.where(data['Category']=='All households', 70, 30)
plt.hlines(y = my_range, xmin = 0, xmax=data['Percent'], color = my_color)
plt.scatter(data['Percent'], my_range, color = my_color, s = my_size, alpha = 1)

# Add titles and axis names
plt.yticks(my_range, data['Category'])
plt.title("Food Insecurity by Household Characteristics")
plt.xlabel('Percentage')
plt.ylabel('Household Characteristics')

# Show the plot
plt.show()

# %%
data = pd.read_excel('/content/drive/My Drive/143 project/verylow2020.xlsx')

# %%
data
# Out:
#                                            Category  Thousands  Percent
# 0                                    All households     5141.0      3.9
# 1                            Household composition:        NaN      NaN
# 2                                With children < 18     1457.0      3.8
# 3                                With children < 6       537.0      3.3
# 4                     Married couples with children      460.0      1.9
# 5                        Single women with children      799.0      8.2
# 6                          Single men with children      181.0      5.5
# 7                       Other household with child1        NaN      NaN
# 8                             With no children < 18     3684.0      4.0
# 9                               More than one adult     1640.0      3.0
# 10                               Women living alone     1073.0      5.1
# 11                                 Men living alone      971.0      5.7
# 12                                     With elderly     1035.0      2.5
# 13                             Elderly living alone      531.0      3.4
# 14  Race/ethnicity of household reference persons2:        NaN      NaN
# 15                               White non-Hispanic     2532.0      3.0
# 16                               Black non-Hispanic     1333.0      8.0
# 17                                        Hispanic3      921.0      5.0
# 18                               Other non-Hispanic      354.0      3.6
# 19              Household income-to-poverty ratio4:        NaN      NaN
# 20                                       Under 1.00     1511.0     14.4
# 21                                       Under 1.30     2146.0     13.0
# 22                                       Under 1.85     2762.0     10.8
# 23                                    1.85 and over     1164.0      1.6
# 24                                   Income unknown     1214.0      3.6
# 25                              Area of residence5:        NaN      NaN
# 26                         Inside metropolitan area     4308.0      3.8
# 27                             In principal cities6     1939.0      5.0
# 28                          Not in principal cities     1685.0      3.0
# 29                        Outside metropolitan area      833.0      4.5
# 30                        Census geographic region:        NaN      NaN
# 31                                        Northeast      733.0      3.3
# 32                                          Midwest     1227.0      4.4
# 33                                            South     2179.0      4.3
# 34                                             West     1002.0      3.4

# %%
my_range = range(1, 36)
plt.figure(figsize = (8,8))
my_color=np.where(data['Category']=='All households', 'orange', 'skyblue')
my_size=np.where(data['Category']=='All households', 70, 30)
plt.hlines(y = my_range, xmin = 0, xmax=data['Percent'], color = my_color)
plt.scatter(data['Percent'], my_range, color = my_color, s = my_size, alpha = 1)

# Add titles and axis names
plt.yticks(my_range, data['Category'])
plt.title("Food Insecurity by Household Characteristics")
plt.xlabel('Percentage')
plt.ylabel('Household Characteristics')

# Show the plot
plt.show()
