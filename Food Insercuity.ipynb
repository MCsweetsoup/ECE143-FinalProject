# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
data = pd.read_excel('2022 food insecurity vs race .xlsx')

# %%
data
# Out:
#     Month  Asian  white  black  Hispanic or Latino  Other race  \
# 0       1   15.3   16.6   24.4                30.0        35.7
# 1       2   20.0   17.3   24.6                31.3        24.7
# 2       3   18.9   12.8   24.1                26.1        19.6
# 3       4   14.1   12.4   41.1                25.3        15.0
# 4       5   17.9   14.9   33.2                30.4        20.7
# 5       6   14.0   16.9   19.2                26.5        31.2
# 6       7   14.3   18.7   24.4                34.5        18.3
# 7       8   10.4   11.8   18.5                21.4        18.8
# 8       9   11.1   11.1   25.0                26.2        25.0
# 9      10   15.7   13.4   23.9                27.2        25.6
# 10     11   17.3   19.2   27.3                28.0        30.4
# 11     12   23.3   16.1   25.0                32.6        35.2
#
#             States  Asian_s  white_s  black_s  Hispanic_s  other_s  overall
# 0       California      9.6     12.4     22.3        26.1     27.2     18.2
# 1            Texas     12.5     17.6     27.2        26.7     18.3     21.9
# 2          Floride      5.4     12.9     22.9        25.6     30.0     18.1
# 3          NewYork      5.6     12.6     23.9        26.0     20.6     16.2
# 4     Pennsylvania     10.5     14.5     18.6        16.5     24.1     15.4
# 5         Illinois     26.2      9.1     28.1        20.7     12.4     13.9
# 6             Ohio      5.1     12.5     28.1        21.0     24.3     15.0
# 7          Georgia      9.4     19.4     28.4        21.2     27.2     21.8
# 8   North Carolina      4.1     14.8     29.5        33.6     41.9     20.9
# 9         Michigan      3.2     14.5     26.5        26.0     20.2     16.9
# 10             NaN      NaN      NaN      NaN         NaN      NaN      NaN
# 11             NaN      NaN      NaN      NaN         NaN      NaN      NaN

# %%
plt.figure(figsize=(7,7))
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
#Asian Plot
plt.plot(data['Asian'],label=r'Asian',c='blue')
plt.plot(data['Asian'], 'bo')

#white plot
plt.plot(data['white'],label=r'White',c='red')
plt.plot(data['white'], 'ro')

#black plot
plt.plot(data['black'],label=r'Black',c='green')
plt.plot(data['black'], 'go')

#Hispanic or Latino plot
plt.plot(data['Hispanic or Latino'],label=r'Hispanic or Latino',c='yellow')
plt.plot(data['Hispanic or Latino'], 'yo')

#Other race plot
plt.plot(data['Other race'],label=r'Other race',c='cyan')
plt.plot(data['Other race'], 'co')

ind = np.arange(len(month)) 

plt.xticks(ind, month)
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.ylabel("Percent %")
plt.title('Food Insecurity VS Race each month In California')
plt.ylim(5, 45)
# Out:
# (5.0, 45.0)

# %%
name= ["Asian",'White','Black','Hispanic','Other race']
average = [data['Asian'].sum()/12,data['white'].sum()/12,data['black'].sum()/12,data['Hispanic or Latino'].sum()/12,data['Other race'].sum()/12]
plt.figure(figsize=(7,7))
plt.bar(name,average,color=['blue', 'red', 'green', 'yellow', 'cyan'])
plt.ylabel("Percent %")
plt.title('Food Insecurity VS Race average In California')
# Out:
# Text(0.5, 1.0, 'Food Insecurity VS Race average In California')

# %%
data
# Out:
#     Month  Asian  white  black  Hispanic or Latino  Other race  \
# 0       1   15.3   16.6   24.4                30.0        35.7
# 1       2   20.0   17.3   24.6                31.3        24.7
# 2       3   18.9   12.8   24.1                26.1        19.6
# 3       4   14.1   12.4   41.1                25.3        15.0
# 4       5   17.9   14.9   33.2                30.4        20.7
# 5       6   14.0   16.9   19.2                26.5        31.2
# 6       7   14.3   18.7   24.4                34.5        18.3
# 7       8   10.4   11.8   18.5                21.4        18.8
# 8       9   11.1   11.1   25.0                26.2        25.0
# 9      10   15.7   13.4   23.9                27.2        25.6
# 10     11   17.3   19.2   27.3                28.0        30.4
# 11     12   23.3   16.1   25.0                32.6        35.2
#
#             States  Asian_s  white_s  black_s  Hispanic_s  other_s  overall
# 0       California      9.6     12.4     22.3        26.1     27.2     18.2
# 1            Texas     12.5     17.6     27.2        26.7     18.3     21.9
# 2          Floride      5.4     12.9     22.9        25.6     30.0     18.1
# 3          NewYork      5.6     12.6     23.9        26.0     20.6     16.2
# 4     Pennsylvania     10.5     14.5     18.6        16.5     24.1     15.4
# 5         Illinois     26.2      9.1     28.1        20.7     12.4     13.9
# 6             Ohio      5.1     12.5     28.1        21.0     24.3     15.0
# 7          Georgia      9.4     19.4     28.4        21.2     27.2     21.8
# 8   North Carolina      4.1     14.8     29.5        33.6     41.9     20.9
# 9         Michigan      3.2     14.5     26.5        26.0     20.2     16.9
# 10             NaN      NaN      NaN      NaN         NaN      NaN      NaN
# 11             NaN      NaN      NaN      NaN         NaN      NaN      NaN

# %%
data['States']
# Out:
# 0         California
# 1              Texas
# 2            Floride
# 3            NewYork
# 4       Pennsylvania
# 5           Illinois
# 6               Ohio
# 7            Georgia
# 8     North Carolina
# 9           Michigan
# 10               NaN
# 11               NaN
# Name: States, dtype: object

# %%
states= ["CA",'TX','FL','NY','PA','IL','OH','GA','NC','MI']

# %%
California = {}
asian = [i for i in data['Asian_s'] if math.isnan(i) == False]
white = [i for i in data['white_s'] if math.isnan(i) == False]
black = [i for i in data['black_s'] if math.isnan(i) == False]
latino =[i for i in data['Hispanic_s'] if math.isnan(i) == False] 
other = [i for i in data['other_s'] if math.isnan(i) == False]

plt.figure(figsize=(7,7))
ind = np.arange(len(states)) 
width = 0.15
plt.bar(ind,asian,width,color="blue",label = 'Asian')
plt.bar(ind+width,white,width,color="red",label = 'White')
plt.bar(ind+width*2,black,width,color="green",label = 'Black')
plt.bar(ind+width*3,latino,width,color="yellow",label = 'Hispanic or Latino')
plt.bar(ind+width*4,other,width,color="cyan",label = 'Other race')
plt.xticks(ind, states)
plt.legend(loc='upper right')
plt.ylabel("Percent%")
plt.title('Food Insecurity VS Race in Each States')
plt.ylim(5, 50)
# Out:
# (5.0, 50.0)

# %%
usa = plt.imread('Image/USA food.png')
plt.figure(figsize=(15,15))
plt.title('Food insecurity for each states')
plt.imshow(usa)
